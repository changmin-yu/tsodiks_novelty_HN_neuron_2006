# %%
from main import *
################# 6-morph-experiment-memory-interference ##############
num_neurons = 120
num_morphs = 30
t_s_corr_list = np.linspace(0,0.50,10)
num_repetition = 1
corr_grd, corr_rnd, morph_idx = main(method=test_memory_interference_exp, num_neurons=num_neurons, num_morphs=num_morphs, 
                                     t_s_corr_list=t_s_corr_list, num_repetitions=num_repetition)
for i in range(len(t_s_corr_list)):
    graph_Wills_Leutgeb(corr_rnd[i], corr_grd[i], morph_idx, t_s_corr_list[i], True)
# Out:
# correlation between the source and the target is:  0.0
# correlation between the source and the target is:  0.05555555555555555
# correlation between the source and the target is:  0.1111111111111111
# correlation between the source and the target is:  0.16666666666666666
# correlation between the source and the target is:  0.2222222222222222
# correlation between the source and the target is:  0.2777777777777778
# correlation between the source and the target is:  0.3333333333333333
# correlation between the source and the target is:  0.38888888888888884
# correlation between the source and the target is:  0.4444444444444444
# correlation between the source and the target is:  0.5
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)

# %%
################ 30-morphs with gradual and mixed order ##############
num_neurons = 400
num_morphs = 30
t_s_corr_list = np.linspace(0,0.7,10)
num_repetition = 1
main(test_FullMorph, num_neurons, num_morphs, t_s_corr_list, num_repetitions=num_repetition)
# Out:
# correlation between the source and the target is:  0.0
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.07777777777777778
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.15555555555555556
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.23333333333333334
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.3111111111111111
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.3888888888888889
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.4666666666666667
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.5444444444444445
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.6222222222222222
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.7
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)

# %%
################# 30-morph-memory-interference ##############
num_neurons = 400
num_morphs = 30
t_s_corr_list = np.linspace(0,0.7,10)
num_repetition = 1
corr_grd, corr_rnd, morph_idx = main(method = test_memory_interference_morph30, num_neurons=num_neurons, num_morphs=num_morphs, 
                                     t_s_corr_list=t_s_corr_list, num_repetitions=num_repetition)
# Out:
# correlation between the source and the target is:  0.0
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.07777777777777778
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.15555555555555556
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.23333333333333334
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.3111111111111111
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.3888888888888889
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.4666666666666667
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.5444444444444445
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.6222222222222222
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# correlation between the source and the target is:  0.7
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:55: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(average_corr_gradual.mean(0),'-.r', c=color1, label='Gradual Morphing', linewidth=3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 t_s_corr_list = np.linspace(0,0.7,10)
#       5 num_repetition = 1
# ----> 6 corr_grd, corr_rnd, morph_idx = main(method = test_memory_interference_morph30, num_neurons=num_neurons, num_morphs=num_morphs,
#       7                                      t_s_corr_list=t_s_corr_list, num_repetitions=num_repetition)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
################ 6-morph-experiment_Wills_Leutgev ##############
num_neurons = 120
num_morphs = 30
t_s_corr_list = np.linspace(0,0.50,10)
num_repetition = 1
corr_rnd, morph_idx = main(method=test_novelty_HN_wills, num_neurons=num_neurons, num_morphs=num_morphs, 
                                  t_s_corr_list=t_s_corr_list, num_repetitions=num_repetition) 
   
corr_grd, morph_idx = main(method=test_novelty_HN_leutgeb, num_neurons=num_neurons, num_morphs=num_morphs, 
                                  t_s_corr_list=t_s_corr_list, num_repetitions=num_repetition)
for i in range(len(t_s_corr_list)):
    graph_Wills_Leutgeb(corr_rnd[i], corr_grd[i], morph_idx, t_s_corr_list[i], False)
# Out:
# correlation between the source and the target is:  0.0
# correlation between the source and the target is:  0.05555555555555555
# correlation between the source and the target is:  0.1111111111111111
# correlation between the source and the target is:  0.16666666666666666
# correlation between the source and the target is:  0.2222222222222222
# correlation between the source and the target is:  0.2777777777777778
# correlation between the source and the target is:  0.3333333333333333
# correlation between the source and the target is:  0.38888888888888884
# correlation between the source and the target is:  0.4444444444444444
# correlation between the source and the target is:  0.5
# correlation between the source and the target is:  0.0
# correlation between the source and the target is:  0.05555555555555555
# correlation between the source and the target is:  0.1111111111111111
# correlation between the source and the target is:  0.16666666666666666
# correlation between the source and the target is:  0.2222222222222222
# correlation between the source and the target is:  0.2777777777777778
# correlation between the source and the target is:  0.3333333333333333
# correlation between the source and the target is:  0.38888888888888884
# correlation between the source and the target is:  0.4444444444444444
# correlation between the source and the target is:  0.5
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
# /Users/weilinran/Desktop/CCSNN/tsodyks_novelty_HN_neuron_2006/utils.py:122: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.r" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(np.arange(1, len(morph_idx)+1), corr_leut.mean(0),'-.r', color=color1, label='Gradual Morphing', linewidth=3)
